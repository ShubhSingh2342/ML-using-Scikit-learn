# %%
# smartphone data generation
import pandas as pd
import numpy as np

# for reproducing the same no 
np.random.seed(42)
num_rows = 1000

data = {
    'camera': np.random.randint(8, 201, size=num_rows),
    'age' : np.random.randint(0, 4, size= num_rows),
    'ram' : np.random.choice([4, 6, 8, 12, 16], size= num_rows),
    'cpu_score' : np.random.randint(40, 101, size= num_rows),
    'sims' : np.random.choice([1, 2], size= num_rows),
    'price' : np.random.randint(8000, 70001, size= num_rows)
}
df = pd.DataFrame(data)
df.head()
# Out:
#    camera  age  ram  cpu_score  sims  price
# 0     110    2    4         89     2  11731
# 1     187    0    4         42     1  64414
# 2     100    2    4         52     1  24835
# 3      22    2    6         82     1  67819
# 4     114    2   12         88     2  35798
